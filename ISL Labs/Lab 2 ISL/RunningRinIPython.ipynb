# %% [markdown]
# ## CS249 -- Spring 2014 -- Principles of Data Mining and Data Science

# %% [markdown]
# To run R within IPython,
#
# (1)  get the rpy2 module for Python with a with something like the following Unix incantation:
#
#      cd /Applications/anaconda    #  or wherever you installed anaconda
#      easy_install rpy2
#
#  (2) start an IPython notebook with something like the following an IPython incantation:
#
#      %load_ext rmagic
#      import rpy2 as Rpy

# %%
# %load_ext rmagic
import rpy2 as Rpy
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-f90e2489a101> in <module>()
# ----> 1 get_ipython().magic(u'load_ext rmagic')
#       2 import rpy2 as Rpy
#
# /Users/shivinkapur/anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.pyc in magic(self, arg_s)
#    2203         magic_name, _, magic_arg_s = arg_s.partition(' ')
#    2204         magic_name = magic_name.lstrip(prefilter.ESC_MAGIC)
# -> 2205         return self.run_line_magic(magic_name, magic_arg_s)
#    2206
#    2207     #-------------------------------------------------------------------------
#
# /Users/shivinkapur/anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.pyc in run_line_magic(self, magic_name, line)
#    2124                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2125             with self.builtin_trap:
# -> 2126                 result = fn(*args,**kwargs)
#    2127             return result
#    2128
#
# /Users/shivinkapur/anaconda/lib/python2.7/site-packages/IPython/core/magics/extension.pyc in load_ext(self, module_str)
#
# /Users/shivinkapur/anaconda/lib/python2.7/site-packages/IPython/core/magic.pyc in <lambda>(f, *a, **k)
#     191     # but it's overkill for just that one bit of state.
#     192     def magic_deco(arg):
# --> 193         call = lambda f, *a, **k: f(*a, **k)
#     194
#     195         if callable(arg):
#
# /Users/shivinkapur/anaconda/lib/python2.7/site-packages/IPython/core/magics/extension.pyc in load_ext(self, module_str)
#      61         if not module_str:
#      62             raise UsageError('Missing module name.')
# ---> 63         res = self.shell.extension_manager.load_extension(module_str)
#      64
#      65         if res == 'already loaded':
#
# /Users/shivinkapur/anaconda/lib/python2.7/site-packages/IPython/core/extensions.pyc in load_extension(self, module_str)
#      96             if module_str not in sys.modules:
#      97                 with prepended_to_syspath(self.ipython_extension_dir):
# ---> 98                     __import__(module_str)
#      99             mod = sys.modules[module_str]
#     100             if self._call_load_ipython_extension(mod):
#
# /Users/shivinkapur/anaconda/lib/python2.7/site-packages/IPython/extensions/rmagic.py in <module>()
#      54 import numpy as np
#      55
# ---> 56 import rpy2.rinterface as ri
#      57 import rpy2.robjects as ro
#      58 try:
#
# ImportError: No module named rpy2.rinterface

# %%
# %R print( "Hello world" )
# Out:
# [1] "Hello world"

# %%
# %R hist(rnorm(1000000), 500, col="cyan")
# Out:
# array([<rpy2.rinterface.SexpVector - Python:0x10688ddc8 / R:0x100964c00>,
#        <rpy2.rinterface.SexpVector - Python:0x10688dd98 / R:0x100965c00>,
#        <rpy2.rinterface.SexpVector - Python:0x10688ddf8 / R:0x100966400>,
#        <rpy2.rinterface.SexpVector - Python:0x10688de10 / R:0x100967400>,
#        <rpy2.rinterface.SexpVector - Python:0x10688de28 / R:0x109382178>,
#        <rpy2.rinterface.SexpVector - Python:0x10688de40 / R:0x1093821a8>], dtype=object)

# %%
# %R data(iris); plot( iris, pch=16, col=c("red","green","blue")[unclass(iris$Species)] )

# %%
# %R pairs( iris )

# %%
# %R data(iris); print( iris[1:15,] )
# Out:
#    Sepal.Length Sepal.Width Petal.Length Petal.Width Species
# 1           5.1         3.5          1.4         0.2  setosa
# 2           4.9         3.0          1.4         0.2  setosa
# 3           4.7         3.2          1.3         0.2  setosa
# 4           4.6         3.1          1.5         0.2  setosa
# 5           5.0         3.6          1.4         0.2  setosa
# 6           5.4         3.9          1.7         0.4  setosa
# 7           4.6         3.4          1.4         0.3  setosa
# 8           5.0         3.4          1.5         0.2  setosa
# 9           4.4         2.9          1.4         0.2  setosa
# 10          4.9         3.1          1.5         0.1  setosa
# 11          5.4         3.7          1.5         0.2  setosa
# 12          4.8         3.4          1.6         0.2  setosa
# 13          4.8         3.0          1.4         0.1  setosa
# 14          4.3         3.0          1.1         0.1  setosa
# 15          5.8         4.0          1.2         0.2  setosa

# %%
# %R data(iris); print( summary(iris) )
# Out:
#   Sepal.Length    Sepal.Width     Petal.Length    Petal.Width
#  Min.   :4.300   Min.   :2.000   Min.   :1.000   Min.   :0.100
#  1st Qu.:5.100   1st Qu.:2.800   1st Qu.:1.600   1st Qu.:0.300
#  Median :5.800   Median :3.000   Median :4.350   Median :1.300
#  Mean   :5.843   Mean   :3.057   Mean   :3.758   Mean   :1.199
#  3rd Qu.:6.400   3rd Qu.:3.300   3rd Qu.:5.100   3rd Qu.:1.800
#  Max.   :7.900   Max.   :4.400   Max.   :6.900   Max.   :2.500
#        Species
#  setosa    :50
#  versicolor:50
#  virginica :50

# %%
# %%R
# hist( iris$Petal.Length, col="aquamarine" )
# hist( iris$Petal.Width, col="cyan" )

# %%
# %%R
# hist( iris$Petal.Length[ iris$Species == "setosa" ], col="aquamarine" )
# hist( iris$Petal.Width[ iris$Species == "setosa" ], col="cyan" )

# %%
# %R install.packages("ISLR")   #  retrieve and install the ISLR package from "cran.r-project.org" (the "mother ship" for R)
# Out:
# --- Please select a CRAN mirror for use in this session ---
# trying URL 'http://cran.stat.ucla.edu/bin/macosx/contrib/3.0/ISLR_1.0.tgz'
# Content type 'application/x-tar' length 2913030 bytes (2.8 Mb)
# opened URL
# ==================================================
# downloaded 2.8 Mb
#
#
# The downloaded binary packages are in
# 	/var/folders/j7/tm2q9d2x6l32yr968jyh6ncw0000gn/T//RtmpX1yJgo/downloaded_packages

# %%
# %%R
# library(ISLR)  #  load in the ISLR package
# print(library(help=ISLR))   # print the help summary for what is in the package
# Out:
# Documentation for package ‘ISLR’
# 		Information on package ‘ISLR’
#
# Description:
#
# Package:            ISLR
# Type:               Package
# Title:              Data for An Introduction to Statistical Learning
#                     with Applications in R
# Version:            1.0
# Date:               2013-06-10
# Author:             Gareth James, Daniela Witten, Trevor Hastie and Rob
#                     Tibshirani
# Maintainer:         Trevor Hastie <hastie@stanford.edu>
# Suggests:           MASS
# Description:        The collection of datasets used in the book "An
#                     Introduction to Statistical Learning with
#                     Applications in R"
# License:            GPL-2
# LazyLoad:           yes
# LazyData:           yes
# URL:                http://www.StatLearning.com
# Packaged:           2013-06-10 19:32:17 UTC; hastie
# Depends:            R (>= 2.10)
# NeedsCompilation:   no
# Repository:         CRAN
# Date/Publication:   2013-06-11 00:17:23
# Built:              R 3.0.2; ; 2014-01-09 22:48:01 UTC; unix
#
# Index:
#
# Auto                    Auto Data Set
# Caravan                 The Insurance Company (TIC) Benchmark
# Carseats                Sales of Child Car Seats
# College                 U.S. News and World Report's College Data
# Default                 Credit Card Default Data
# Hitters                 Baseball Data
# Khan                    Khan Gene Data
# NCI60                   NCI 60 Data
# OJ                      Orange Juice Data
# Portfolio               Portfolio Data
# Smarket                 S&P Stock Market Data
# Wage                    Mid-Atlantic Wage Data
# Weekly                  Weekly S&P Stock Market Data

# %%
# %R print( summary(Auto) )
# Out:
#       mpg          cylinders      displacement     horsepower        weight
#  Min.   : 9.00   Min.   :3.000   Min.   : 68.0   Min.   : 46.0   Min.   :1613
#  1st Qu.:17.00   1st Qu.:4.000   1st Qu.:105.0   1st Qu.: 75.0   1st Qu.:2225
#  Median :22.75   Median :4.000   Median :151.0   Median : 93.5   Median :2804
#  Mean   :23.45   Mean   :5.472   Mean   :194.4   Mean   :104.5   Mean   :2978
#  3rd Qu.:29.00   3rd Qu.:8.000   3rd Qu.:275.8   3rd Qu.:126.0   3rd Qu.:3615
#  Max.   :46.60   Max.   :8.000   Max.   :455.0   Max.   :230.0   Max.   :5140
#
#   acceleration        year           origin                      name
#  Min.   : 8.00   Min.   :70.00   Min.   :1.000   amc matador       :  5
#  1st Qu.:13.78   1st Qu.:73.00   1st Qu.:1.000   ford pinto        :  5
#  Median :15.50   Median :76.00   Median :1.000   toyota corolla    :  5
#  Mean   :15.54   Mean   :75.98   Mean   :1.577   amc gremlin       :  4
#  3rd Qu.:17.02   3rd Qu.:79.00   3rd Qu.:2.000   amc hornet        :  4
#  Max.   :24.80   Max.   :82.00   Max.   :3.000   chevrolet chevette:  4
#                                                  (Other)           :365

# %%
# %R print( Auto[1:15, ] )
# Out:
#    mpg cylinders displacement horsepower weight acceleration year origin
# 1   18         8          307        130   3504         12.0   70      1
# 2   15         8          350        165   3693         11.5   70      1
# 3   18         8          318        150   3436         11.0   70      1
# 4   16         8          304        150   3433         12.0   70      1
# 5   17         8          302        140   3449         10.5   70      1
# 6   15         8          429        198   4341         10.0   70      1
# 7   14         8          454        220   4354          9.0   70      1
# 8   14         8          440        215   4312          8.5   70      1
# 9   14         8          455        225   4425         10.0   70      1
# 10  15         8          390        190   3850          8.5   70      1
# 11  15         8          383        170   3563         10.0   70      1
# 12  14         8          340        160   3609          8.0   70      1
# 13  15         8          400        150   3761          9.5   70      1
# 14  14         8          455        225   3086         10.0   70      1
# 15  24         4          113         95   2372         15.0   70      3
#                         name
# 1  chevrolet chevelle malibu
# 2          buick skylark 320
# 3         plymouth satellite
# 4              amc rebel sst
# 5                ford torino
# 6           ford galaxie 500
# 7           chevrolet impala
# 8          plymouth fury iii
# 9           pontiac catalina
# 10        amc ambassador dpl
# 11       dodge challenger se
# 12        plymouth 'cuda 340
# 13     chevrolet monte carlo
# 14   buick estate wagon (sw)
# 15     toyota corona mark ii
