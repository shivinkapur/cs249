# %% [markdown]
# # Mini-Homework 2:  Baby Names

# %% [markdown]
# The goal of this assignment is simple:  to adapt Hadley Wickham's R scripts for Baby Names to work with IPython (and solve the problems he states in his scripts).
#
# All of these scripts, and the data, are available from https://github.com/hadley/data-baby-names
#
# The examples are also reproduced (in IPython + Pandas) in our [PDA] text (i.e., Python for Data Analysis -- described in the syllabus).  So the goal is to get the examples in the [PDA] text working here.
#
# I have gotten some of this working by cutting and pasting the R scripts into IPython notebook cells.  Please complete this job so that the scripts work, and solve the problem at the end.

# %% [markdown]
# ## start up R within IPython

# %%
# %load_ext rmagic
import rpy2 as Rpy

# %% [markdown]
# ## load some libraries (installing them if necessary)

# %%
# %%R
#
# not.installed = function(package_name)  !is.element(package_name, installed.packages()[,1])
#
# if (not.installed("RCurl")) install.packages("RCurl")
# if (not.installed("plyr")) install.packages("plyr")
# if (not.installed("ggplot2")) install.packages("ggplot2")
#
#
# #  To complete this assignment, you must learn something about plyr and ggplot2.
# #  However:  these packages are state-of-the-art data science.
# #
# #  plyr is sort of a generalized "map-reduce"+"group-by" library for R;  it is very popular.
# #
# #  ggplot2 is a relatively new graphics package that is also extremely popular.
# #
# #  By the way:  Hadley Wickham developed both the plyr and ggplot2 packages.
#
# #  See his slides  SlidesAboutPlyrForTheBabyNamesDataset.pdf   (included here) to get an introduction.
#
#
# library(RCurl)
# library(plyr)
# library(ggplot2)
# Out:
# Loading required package: bitops

# %% [markdown]
# ## NOTICE:  the plotting routines here give very nice output, but are SLOW.  Please be patient.

# %% [markdown]
# ## Start by reading in the Baby Names data

# %%
# %%R
# #  Baby names data is obtainable from the Social Security Administration at:
# #   http://www.ssa.gov/cgi-bin/popularnames.cgi
# #  The file 1-download.r explains how to do this in R if you are interested.
# #
# #  Here we simply use the file "baby-names.csv", which covers names during 1880-2008.
#
#
# #### NOTE:  please replace the filename  "baby-names.csv"  by  _a_filename_with_full_path_
# #### saying where you downloaded this file.  Alternatively put baby-names.csv in
# #### the same directory where you put this notebook.
#
#
# bnames <- read.csv("baby-names.csv", stringsAsFactors = FALSE)
#
# print(dim(bnames))
#
# print(summary(bnames))
# Out:
# [1] 258000      4
#       year          name              percent              sex
#  Min.   :1880   Length:258000      Min.   :0.0000260   Length:258000
#  1st Qu.:1912   Class :character   1st Qu.:0.0000810   Class :character
#  Median :1944   Mode  :character   Median :0.0001640   Mode  :character
#  Mean   :1944                      Mean   :0.0008945
#  3rd Qu.:1976                      3rd Qu.:0.0005070
#  Max.   :2008                      Max.   :0.0815410

# %%
# %%R
#
#
# # Note:  this data was generated a few years ago, so it stops in 2008.
# #
# # If you'd like to update this data, then in the text "Python for Data Analysis" on p. 32
# # it is explained how to download the raw data from
# #
# #    http://www.ssa.gov/oact/babynames/limits.html
# #
# # and convert it (using Python) to a format like the .csv file used in this notebook.
# Out:
# UsageError: %%R is a cell magic, but the cell body is empty. Did you mean the line magic %R (single %)?

# %% [markdown]
# ## determine the history of percentages covered by the top 1000 baby names

# %%
# %%R -w 600 -h 400
#
# bnames$sex <- factor(bnames$sex, levels = c("girl", "boy"))
#
# sump <- colwise(sum, "percent")
#
# # Investigate the percentage of all names that the top 1000 baby names cover
#
# bnames_coverage <- ddply(bnames, .(year, sex), sump)
# #print(bnames_coverage)
#
#
# # Recently trending down - names are become more diverse?
# print(qplot(year, percent, data = bnames_coverage, color = sex, geom = "line") + ylim(0, 1))

# %% [markdown]
# ## The last letters of names show surprising trends over time

# %% [markdown]
# In 2007, Laura Wattenberg (http://www.babynamewizard.com) noticed that the distribution of final letters of boy names has
# changed significantly over the last 100 years.  We can analyze this change, and explore the change for girls as well.

# %%
# %%R -w 900 -h 900
#
# # Helper function to extract letter at given position.  Negative values
# # index from rear of string.
#
# letter <- function(string, pos) {
#   if (pos > 0) {
#     substr(string, pos, pos)
#   } else {
#     nc <- nchar(string)
#     substr(string, nc + pos + 1, nc + pos + 1)
#   }
# }
#
# axes <- list(
#   scale_x_continuous(breaks = c(1900, 1950, 2000)),
#   scale_y_continuous("", limits = c(0, 0.4)) ## , formatter = "percent")
# )
#
# # Last letter
# ll <- ddply(bnames, .(year, sex, last = letter(name, -1)), sump)
# #print(ll)
#
# print(qplot(year, percent, data = ll, color = sex, geom = "line") +
#   facet_wrap(~ last) + axes)
#
# print(last_plot() + scale_y_log10())
# Out:
# Scale for 'y' is already present. Adding another scale for 'y', which will replace the existing scale.

# %% [markdown]
# ## Idea:  does this also hold for the first or second letter?

# %%
# %%R -w 900 -h 900
#
# # First letter
# fl <- ddply(bnames, .(year, sex, first = letter(name, 1)), sump)
#
# print(qplot(year, percent, data = fl, color = sex, geom = "line") +
#   facet_wrap(~ first) + axes)
#
# # Second letter?
# sl <- ddply(bnames, .(year, sex, second = letter(name, 2)), sump)
#
# print(qplot(year, percent, data = sl, color = sex, geom = "line") +
#   facet_wrap(~ second) + axes)

# %% [markdown]
# # Problem 1: plot the histograms of last-letter frequencies in 1908, in 1958, and in 2008.

# %%
# %%R -h 900 -w 900
#
# # Last letter
# #1908
# ll1 <- ddply(bnames, .(year ==1908 ,last = letter(name, -1)), sump)
# print(ll1)
# print(qplot(last,percent, data=ll1, geom="histogram", stat="identity", main="Year 1908"))
#
# #1958
# ll2 <- ddply(bnames, .(year ==1958 ,last = letter(name, -1)), sump)
# print(ll2)
# print(qplot(last,percent, data=ll2, geom="histogram", stat="identity", main="Year 1958"))
#
# #2008
# ll3 <- ddply(bnames, .(year ==2008 ,last = letter(name, -1)), sump)
# #print(ll1)
# print(qplot(last,percent, data=ll3, geom="histogram", stat="identity", main="Year 2008"))
#
#
# #Manoj
# names_new = subset(bnames, year == c(1908,1958,2008))
# fl <- ddply(names_new, .(year,last = letter(name, -1)), sump)
# print(qplot(last, percent, data = fl, geom = "histogram", stat="identity") +
#   facet_wrap(~ year))
# Out:
#    year == 1908 last   percent
# 1         FALSE    a 36.262442
# 2         FALSE    b  0.670277
# 3         FALSE    c  0.827372
# 4         FALSE    d 13.636736
# 5         FALSE    e 40.767587
# 6         FALSE    f  0.101897
# 7         FALSE    g  0.334411
# 8         FALSE    h 10.022560
# 9         FALSE    i  1.636464
# 10        FALSE    j  0.001418
# 11        FALSE    k  4.045055
# 12        FALSE    l 13.414133
# 13        FALSE    m  5.721545
# 14        FALSE    n 32.674302
# 15        FALSE    o  2.121578
# 16        FALSE    p  0.467085
# 17        FALSE    q  0.001690
# 18        FALSE    r  9.169325
# 19        FALSE    s 16.602930
# 20        FALSE    t  9.682796
# 21        FALSE    u  0.108500
# 22        FALSE    v  0.008991
# 23        FALSE    w  1.707753
# 24        FALSE    x  0.378903
# 25        FALSE    y 28.454435
# 26        FALSE    z  0.138205
# 27         TRUE    a  0.253557
# 28         TRUE    b  0.001876
# 29         TRUE    c  0.001905
# 30         TRUE    d  0.119270
# 31         TRUE    e  0.436686
# 32         TRUE    f  0.000769
# 33         TRUE    g  0.002201
# 34         TRUE    h  0.091131
# 35         TRUE    i  0.002213
# 36         TRUE    k  0.033442
# 37         TRUE    l  0.101062
# 38         TRUE    m  0.057027
# 39         TRUE    n  0.198276
# 40         TRUE    o  0.013157
# 41         TRUE    p  0.002765
# 42         TRUE    r  0.072449
# 43         TRUE    s  0.154786
# 44         TRUE    t  0.090978
# 45         TRUE    u  0.000844
# 46         TRUE    v  0.000132
# 47         TRUE    w  0.005662
# 48         TRUE    x  0.003600
# 49         TRUE    y  0.169188
# 50         TRUE    z  0.002238
#    year == 1958 last   percent
# 1         FALSE    a 36.213388
# 2         FALSE    b  0.670206
# 3         FALSE    c  0.823386
# 4         FALSE    d 13.629679
# 5         FALSE    e 40.925899
# 6         FALSE    f  0.099817
# 7         FALSE    g  0.329796
# 8         FALSE    h 10.038742
# 9         FALSE    i  1.607624
# 10        FALSE    j  0.001418
# 11        FALSE    k  4.032310
# 12        FALSE    l 13.378280
# 13        FALSE    m  5.737308
# 14        FALSE    n 32.603551
# 15        FALSE    o  2.122666
# 16        FALSE    p  0.464525
# 17        FALSE    q  0.001690
# 18        FALSE    r  9.208838
# 19        FALSE    s 16.641620
# 20        FALSE    t  9.693931
# 21        FALSE    u  0.108698
# 22        FALSE    v  0.009069
# 23        FALSE    w  1.706686
# 24        FALSE    x  0.380821
# 25        FALSE    y 28.323449
# 26        FALSE    z  0.139850
# 27         TRUE    a  0.302611
# 28         TRUE    b  0.001947
# 29         TRUE    c  0.005891
# 30         TRUE    d  0.126327
# 31         TRUE    e  0.278374
# 32         TRUE    f  0.002849
# 33         TRUE    g  0.006816
# 34         TRUE    h  0.074949
# 35         TRUE    i  0.031053
# 36         TRUE    k  0.046187
# 37         TRUE    l  0.136915
# 38         TRUE    m  0.041264
# 39         TRUE    n  0.269027
# 40         TRUE    o  0.012069
# 41         TRUE    p  0.005325
# 42         TRUE    r  0.032936
# 43         TRUE    s  0.116096
# 44         TRUE    t  0.079843
# 45         TRUE    u  0.000646
# 46         TRUE    v  0.000054
# 47         TRUE    w  0.006729
# 48         TRUE    x  0.001682
# 49         TRUE    y  0.300174
# 50         TRUE    z  0.000593

# %% [markdown]
# # Problem 2: please fix the following code (by Hadley Wickham) so that it works

# %% [markdown]
# ## To get more insight, reduce the number of names

# %%
# %%R -h 900 -w 900
#
# # The complete data set takes a long time to work with, so we want to limit it
# # to names that plenty of data: i.e. that they've been in the top 1000 for
# # both boys and girls, and there are a decent number of babies with those
# # names.
#
# # prop = bnames$percent
#
# # Your turn:  create a summary that for each name, gives:
# #   * total percentage of babies with that name
# #   * the total percentage of boys
# #   * the total percentage of girls
# #   * the number of years the name was in the top 1000 as a girls name
# #   * the number of years the name was in the top 1000 as a boys name
# #
# # Hint: Start with a single name and figure out how to solve the problem
# # Hint: Use summarize
#
# ## Solution:
# ##  We can use ddply to convert a data.frame to a data.frame
# ##  by applying a function -- in this case 'summarize' -- to the data.
# ##  The ddply function lets you name the columns of the resulting data.frame.
#
# ## solution:
#
# times <-
# ddply(bnames,
#       c("name"),
#       summarize,
#          boys = sum(percent[sex == "boy"]),
#          boys_n = sum(sex == "boy"),
#          girls = sum(percent[sex == "girl"]),
#          girls_n = sum(sex == "girl"),
#          .progress = "text"
# )
#
# # ~7000 names in total - want to limit to under 200. In real-life would
# # probably use more, but starting with a subset for easier comprehension isn't
# # a bad idea.
#
# nrow(times)
# print(nrow(times))
#
# # At absolute minimum need at least 1 year each in top 1000.  This cuts it
# # down to 582 names.
#
# times <- subset(times, boys_n > 1 & girls_n > 1)
# print(times)
#
# # Use basic graphics to figure out good cut-offs
# ###  These plots take a long time....................................
#
# print(qplot(boys_n, girls_n, data = times))
#
# print(qplot(log10(boys), log10(girls), data = times))
#
# print(qplot(pmin(boys_n, girls_n), data = times, binwidth = 1))
# Out:
#   |======================================================================| 100%
# [1] 6782
#             name     boys boys_n    girls girls_n
# 4          Aaron 0.292292    129 0.000805       9
# 9          Abbie 0.000092      2 0.022804      94
# 32           Ada 0.000569     10 0.184069     111
# 44         Addie 0.001293     20 0.083583      82
# 45       Addison 0.008527     75 0.021231      15
# 77        Adrian 0.093318    129 0.005909      43
# 93         Agnes 0.000784     13 0.275131      92
# 128       Albert 0.697036    129 0.000822      15
# 165         Alex 0.165949    129 0.002610      17
# 168    Alexander 0.324048    129 0.000828       7
# 177       Alexis 0.024625     51 0.147704      65
# 195          Ali 0.008242     40 0.002530      18
# 198        Alice 0.002508     34 0.712123     129
# 221        Allie 0.006896     52 0.048145      93
# 223      Allison 0.003036     49 0.130190      63
# 229         Alma 0.002875     36 0.228557     129
# 248        Alpha 0.001606     22 0.012259      63
# 256         Alta 0.000159      3 0.050335      77
# 262         Alva 0.023074     82 0.009943      71
# 298       Amanda 0.000708     12 0.467291     129
# 302        Amari 0.002880     12 0.003699      13
# 335          Amy 0.000387      8 0.418477     129
# 354        Andra 0.000677     16 0.000791      10
# 357       Andrea 0.002206     33 0.223769     121
# 360       Andrew 0.785335    129 0.000783       8
# 364        Angel 0.081914    103 0.043663      53
# 365       Angela 0.000371      8 0.378897     129
# 392         Anna 0.004762     38 1.195867     129
# 407        Annie 0.002943     39 0.536240     129
# 416      Anthony 0.814686    129 0.002088      24
# 425      Antonia 0.000645     14 0.024365     127
# 449       Ardell 0.000927     19 0.001533      27
# 452        Arden 0.004867     62 0.000182       3
# 468        Ariel 0.006684     42 0.025028      31
# 485        Arlie 0.008356     77 0.002074      34
# 497       Armani 0.001902     15 0.001499      11
# 523       Arthur 0.753998    129 0.001517      28
# 524        Artie 0.004872     74 0.011964      63
# 547       Ashley 0.009702     91 0.417707      45
# 553       Ashton 0.018819     34 0.008132      20
# 568       Aubrey 0.029222    123 0.022226      36
# 570        Audie 0.001396     27 0.002688      36
# 573       Audrey 0.001950     33 0.166544     129
# 580      Augusta 0.001024     16 0.040019      65
# 584    Augustine 0.008367    104 0.002946      51
# 594       Austin 0.191477    129 0.000211       2
# 606        Avery 0.022645    129 0.020847      20
# 626         Baby 0.002553     22 0.001945      15
# 629       Bailey 0.010486     49 0.034669      26
# 637      Barbara 0.002390     34 1.001579     129
# 661     Beatrice 0.000508      8 0.235323     123
# 673          Bee 0.001588     24 0.000103       2
# 697       Bennie 0.059009    112 0.009951      76
# 714      Bernice 0.004353     52 0.196985     104
# 719         Bert 0.068600    104 0.000201       4
# 721       Bertha 0.002260     27 0.439582     106
# 722       Bertie 0.001879     24 0.029219      68
# 727        Beryl 0.002014     35 0.011647      78
# 730       Bessie 0.001625     23 0.386658      95
# 735       Bethel 0.000114      2 0.003577      47
# 742        Betty 0.002414     25 0.817489     117
# 751      Beverly 0.005556     69 0.251523      95
# 757       Billie 0.028315    102 0.075893     111
# 758        Billy 0.262495    127 0.002198      26
# 761         Bird 0.000384      7 0.000409       6
# 771        Blair 0.008694    104 0.004294      21
# 773        Blake 0.064506     78 0.000801       8
# 777      Blanche 0.000493      9 0.187259      85
# 788       Bobbie 0.013703     72 0.061533     113
# 789        Bobby 0.202844     98 0.004766      40
# 794       Bonnie 0.004748     67 0.220895     123
# 826      Brandon 0.351125     59 0.000998       8
# 828       Brandy 0.000370      7 0.058971      41
# 847       Brenda 0.000123      4 0.330294      81
# 861        Brian 0.605216     84 0.001304      14
# 885        Britt 0.001323     26 0.000321       4
# 890     Brittany 0.000205      3 0.181090      38
# 904        Brook 0.000841     17 0.004100      30
# 951      Burnice 0.000107      2 0.000300       6
# 964         Byrd 0.000882     14 0.000614      10
# 988       Callie 0.000636     12 0.049969     118
# 993      Cameron 0.102693     90 0.009992      29
# 997      Camille 0.000238      5 0.034473     129
# 1000    Campbell 0.000495      8 0.001060       6
# 1003      Camryn 0.000380      4 0.008073      12
# 1022       Carey 0.012746    113 0.005953      35
# 1029        Carl 0.529010    129 0.000489      10
# 1038      Carlie 0.000382      7 0.004837      24
# 1054      Carmen 0.012519     83 0.083567     128
# 1058       Carol 0.006897     62 0.529425     126
# 1064     Carolyn 0.000308      7 0.372150     129
# 1070      Carrie 0.001085     18 0.343487     128
# 1071      Carrol 0.005358     52 0.001966      21
# 1072     Carroll 0.038070     98 0.002940      33
# 1075      Carson 0.032452    126 0.001827      13
# 1077        Cary 0.015795    109 0.001531      19
# 1083       Casey 0.054822     85 0.038033      42
# 1093     Cassidy 0.000604      9 0.022191      28
# 1100   Catherine 0.000329      6 0.603445     129
# 1117       Cecil 0.127712    118 0.014267      64
# 1154    Chandler 0.012297     31 0.002587      11
# 1174     Charles 2.518147    129 0.010478      93
# 1176     Charlie 0.282084    129 0.008264      76
# 1189       Chase 0.052249     38 0.000347       3
# 1223    Cheyenne 0.000089      2 0.028530      29
# 1231       Chris 0.083447    129 0.011159      36
# 1243   Christian 0.174223    129 0.008931      39
# 1247   Christina 0.000296      6 0.275454     129
# 1252 Christopher 1.029456    129 0.004088      25
# 1253     Christy 0.000097      2 0.054813      62
# 1276       Clair 0.016104     85 0.000152       3
# 1277      Claire 0.002490     39 0.097850     129
# 1278       Clara 0.002143     27 0.471546     129
# 1281       Clare 0.004659     57 0.020315     116
# 1282    Clarence 0.495593    129 0.000176       3
# 1294      Claude 0.150687    114 0.000740      12
# 1297     Claudie 0.003144     49 0.005591      58
# 1320        Cleo 0.013671     76 0.036123      77
# 1334    Clifford 0.196917    126 0.001497      25
# 1346       Clyde 0.193020    119 0.007433      53
# 1353        Cody 0.130596     62 0.001416      13
# 1391      Connie 0.007484     82 0.159937     119
# 1403        Cora 0.000786     13 0.237341     129
# 1420       Corey 0.089930     60 0.003918      26
# 1439     Cortney 0.001053     15 0.008268      27
# 1441        Cory 0.063318     57 0.002292      19
# 1446    Courtney 0.011713     88 0.132363      51
# 1470        Cruz 0.006901     92 0.000811      15
# 1482     Cynthia 0.000251      8 0.388625     129
# 1495       Daisy 0.000294      6 0.168305     129
# 1499      Dakota 0.036655     24 0.010175      19
# 1501        Dale 0.181679    128 0.012435      65
# 1503      Dallas 0.037584    129 0.001722      10
# 1518        Dana 0.031065    118 0.104856     105
# 1530      Daniel 1.098732    129 0.002200      18
# 1534    Danielle 0.000156      3 0.190915      69
# 1550       Darby 0.000357      7 0.001535       9
# 1553       Darcy 0.000462     14 0.009761      46
# 1557      Darian 0.005848     38 0.002294       9
# 1591       Daryl 0.032946     85 0.000903      13
# 1599        Dave 0.066550    114 0.000084       2
# 1602       David 2.159018    129 0.006651      66
# 1627        Dean 0.101680    129 0.000826      16
# 1646     Deborah 0.000418     11 0.389845     129
# 1648       Debra 0.000257      7 0.281217      65
# 1655         Dee 0.011087     86 0.008823      61
# 1683        Dell 0.003731     64 0.001840      25
# 1778       Devan 0.005250     26 0.001257       8
# 1782       Devin 0.064968     52 0.007566      28
# 1783       Devon 0.030668     49 0.008786      29
# 1787       Devyn 0.002141     16 0.002246      16
# 1790       Dewey 0.048041     99 0.000528       3
# 1828       Dixie 0.000208      4 0.031403     103
# 1842     Dolores 0.000386      8 0.172182     109
# 1855   Dominique 0.009692     36 0.024897      43
# 1856    Dominque 0.000583      7 0.001221      10
# 1857   Domonique 0.000196      3 0.001894      13
# 1862      Donald 1.034592    129 0.002059      23
# 1873       Donna 0.000471     14 0.499764     128
# 1875      Donnie 0.034025     97 0.007860      75
# 1881        Dora 0.000711     10 0.178232     113
# 1893       Doris 0.002850     39 0.398338     113
# 1898     Dorothy 0.004039     48 1.065111     126
# 1900      Dorris 0.000497     11 0.006520      53
# 1926        Drew 0.032660     83 0.001391      10
# 1944       Dusty 0.004465     44 0.001260      10
# 1954       Dylan 0.130252     43 0.001846       9
# 1958        Earl 0.391530    127 0.000988      19
# 1963      Earlie 0.001949     32 0.000156       3
# 1985       Eddie 0.189091    129 0.016762      79
# 1992       Edith 0.001215     19 0.400651     129
# 1998        Edna 0.001909     25 0.476161     111
# 2007      Edward 1.427891    129 0.002578      40
# 2014       Effie 0.000634     11 0.112652      80
# 2081      Elisha 0.011593     95 0.005480      29
# 2085   Elizabeth 0.004318     62 1.392100     129
# 2090        Ella 0.000946     16 0.346483     124
# 2094       Ellen 0.000108      2 0.265680     129
# 2098       Ellie 0.001292     20 0.016373      67
# 2107       Elmer 0.231324    128 0.000858      16
# 2127       Elsie 0.001586     22 0.288639     100
# 2131        Elva 0.000360      7 0.042727      91
# 2134       Elvie 0.000127      2 0.003105      45
# 2146        Elza 0.004427     45 0.000123       3
# 2158     Emerson 0.014698    112 0.002356       7
# 2159       Emery 0.019296    100 0.000898       4
# 2170        Emma 0.002475     27 0.648518     129
# 2208        Eric 0.451479    129 0.001244      15
# 2213        Erie 0.000189      4 0.001545      25
# 2216        Erin 0.003896     34 0.164143      58
# 2229      Ernest 0.398502    129 0.000155       3
# 2251       Essie 0.001471     20 0.064095      82
# 2262       Ester 0.000297      5 0.011965      86
# 2265      Esther 0.000678     10 0.315523     129
# 2272       Ethel 0.003302     32 0.529391      96
# 2286      Eugene 0.390062    129 0.000780      14
# 2290        Eula 0.000116      2 0.071965      81
# 2295      Eunice 0.000482      8 0.095267     113
# 2300         Eva 0.000907     13 0.342956     129
# 2314      Evelyn 0.000493      8 0.463033     129
# 2347      Fannie 0.000298      4 0.180080      88
# 2359         Fay 0.008287     63 0.036758      89
# 2379        Fern 0.000257      4 0.046282      82
# 2393      Finley 0.001912     26 0.000651       4
# 2413       Flora 0.000100      2 0.114739      93
# 2415    Florence 0.003810     34 0.598001     102
# 2426        Floy 0.000174      3 0.012225      61
# 2427       Floyd 0.204836    119 0.000166       3
# 2431      Forest 0.019425    103 0.000110       2
# 2432     Forrest 0.046605    124 0.000097       2
# 2438     Frances 0.007191     66 0.663941     129
# 2444     Francis 0.329493    129 0.032006     100
# 2449       Frank 1.339841    129 0.004724      59
# 2450     Frankie 0.022892    103 0.028937      95
# 2455        Fred 0.589056    123 0.001374      21
# 2457     Freddie 0.053142    123 0.008837      71
# 2485     Gabriel 0.123862    129 0.001690      14
# 2493        Gail 0.008446     75 0.120848     104
# 2496        Gale 0.009868     72 0.010456      37
# 2506      Garnet 0.001018     18 0.007505      59
# 2507     Garnett 0.003934     61 0.002677      41
# 2516        Gary 0.505097    126 0.000191       4
# 2523         Gay 0.000482      9 0.012332      79
# 2526       Gayle 0.003432     45 0.036200      76
# 2539        Gene 0.096173    119 0.006195      62
# 2545       Genie 0.000108      2 0.001213      17
# 2554      George 2.096747    129 0.010546      76
# 2560     Georgia 0.000127      2 0.165134     129
# 2568      Gerald 0.328011    129 0.000185       4
# 2578    Germaine 0.000571      9 0.005216      51
# 2583       Gerry 0.007357     54 0.003943      38
# 2586    Gertrude 0.001258     18 0.356927      86
# 2626      Gladys 0.001315     16 0.359171     119
# 2631       Glenn 0.192266    129 0.000762      14
# 2637      Gloria 0.000193      5 0.275470     112
# 2645      Golden 0.002841     37 0.002141      32
# 2647      Goldie 0.000337      5 0.061760      79
# 2654       Grace 0.001864     24 0.551647     129
# 2688      Grover 0.061048     95 0.000093       2
# 2689   Guadalupe 0.016516    116 0.037078     128
# 2699      Gussie 0.000718     12 0.026303      67
# 2717      Hadley 0.000175      2 0.002092      10
# 2734      Hallie 0.002298     28 0.027805      95
# 2760      Harley 0.039426    129 0.006813      18
# 2768      Harold 0.601335    129 0.000987      16
# 2769      Harper 0.001209     16 0.001485       5
# 2778       Harry 0.794950    129 0.001071      15
# 2792      Hattie 0.000774     12 0.218797      89
# 2794      Hayden 0.032427     74 0.004164      11
# 2803       Hazel 0.004295     51 0.347024     107
# 2808     Heather 0.000142      3 0.294524      74
# 2818       Helen 0.005110     55 1.234222     129
# 2834       Henry 0.959094    129 0.004603      61
# 2853      Hester 0.000107      2 0.025514      71
# 2862      Hilary 0.000622     12 0.011423      45
# 2871     Hillary 0.000114      2 0.013592      44
# 2888      Hollie 0.000963     13 0.007676      35
# 2889      Hollis 0.013565     94 0.000414       7
# 2890       Holly 0.000269      5 0.106061      72
# 2907      Howard 0.403105    129 0.000089       2
# 2926      Hunter 0.078920    110 0.004055      12
# 2940         Ida 0.001465     21 0.394939     105
# 2974      Infant 0.001591     12 0.001210       8
# 2983         Ira 0.082493    113 0.005855      65
# 2986       Irene 0.000933     13 0.413730     129
# 3029         Iva 0.000287      5 0.067576      82
# 3040       Ivory 0.006893     90 0.001506      25
# 3041         Ivy 0.003721     50 0.025178     128
# 3058        Jack 0.560518    129 0.000952      16
# 3061      Jackie 0.049527     80 0.052820      90
# 3078        Jade 0.001968     31 0.028491      34
# 3079       Jaden 0.021701     15 0.005476      13
# 3082       Jadyn 0.000914      8 0.004308      10
# 3093      Jaiden 0.005485     10 0.002775      10
# 3094      Jaidyn 0.000429      4 0.001563       8
# 3097       Jaime 0.031150     67 0.027227      44
# 3099      Jaimie 0.000084      2 0.003837      20
# 3125       James 4.574991    129 0.018859     110
# 3129       Jamie 0.044978     80 0.144704     102
# 3136      Jammie 0.000547      8 0.000763       6
# 3138         Jan 0.011243     67 0.029259      54
# 3149       Janet 0.000070      2 0.361150     129
# 3153      Janice 0.000072      2 0.252502     107
# 3192       Jason 0.542213    128 0.002354      16
# 3210      Jayden 0.034499     15 0.006331      11
# 3219      Jaylen 0.009500     16 0.000432       3
# 3221      Jaylin 0.003261     15 0.001759       9
# 3225       Jayme 0.000912     17 0.005547      31
# 3238        Jean 0.019051    129 0.370781     115
# 3260     Jeffrey 0.502547     75 0.000209       3
# 3272      Jennie 0.000505      8 0.232840     118
# 3273    Jennifer 0.002142     23 0.820391      71
# 3317       Jerry 0.409608    129 0.011783      60
# 3323       Jesse 0.354253    129 0.005438      51
# 3327     Jessica 0.001340     15 0.551641     105
# 3328      Jessie 0.131579    129 0.261805     129
# 3338       Jewel 0.005710     62 0.034634     102
# 3339      Jewell 0.005526     59 0.031518      83
# 3345      Jimmie 0.096594    122 0.023314      83
# 3349        Joan 0.001550     22 0.357570     114
# 3362       Jodie 0.002447     33 0.014059      55
# 3363        Jody 0.015696     51 0.029433      49
# 3364         Joe 0.508141    129 0.009856      81
# 3374        Joey 0.024903     70 0.001350      12
# 3380        John 5.299585    129 0.020775     109
# 3384      Johnie 0.033044     92 0.005583      53
# 3386     Johnnie 0.107408    122 0.045693      94
# 3387      Johnny 0.188780    129 0.000154       3
# 3401    Jonathan 0.391095    129 0.000753       8
# 3407      Jonnie 0.002439     41 0.003020      49
# 3408      Jordan 0.153443    125 0.059425      31
# 3414      Jordyn 0.000643      6 0.014606      20
# 3428      Joseph 2.292487    129 0.007306      86
# 3429   Josephine 0.000706     12 0.373796     129
# 3433      Joshua 0.565345    129 0.001601      12
# 3448         Joy 0.000844     16 0.080879     123
# 3449       Joyce 0.001527     26 0.351575     125
# 3461      Judith 0.000485      9 0.296066     129
# 3463        Judy 0.000242      6 0.232676     101
# 3465        Jule 0.001279     17 0.000360       7
# 3468       Julia 0.000734     11 0.430880     129
# 3484        June 0.004098     57 0.148964     108
# 3491     Justice 0.005240     18 0.004889      15
# 3492      Justin 0.373250    125 0.001116      10
# 3494     Justine 0.000522      9 0.022638     125
# 3543     Kameron 0.009071     23 0.000335       3
# 3564       Karen 0.000696     19 0.542034      94
# 3595       Kasey 0.005016     38 0.015404      39
# 3613   Katherine 0.000121      2 0.481973     129
# 3638         Kay 0.002462     30 0.065526      92
# 3641      Kayden 0.004841     10 0.001442       6
# 3643        Kaye 0.000145      3 0.007006      38
# 3688      Kelley 0.002709     45 0.024389      44
# 3691       Kelly 0.047194    123 0.255616      62
# 3693      Kelsey 0.001782     27 0.068912      32
# 3701      Kendal 0.000374      6 0.002115      14
# 3702     Kendall 0.016373     94 0.018150      32
# 3713     Kennedy 0.001537     21 0.016457      15
# 3714     Kenneth 0.834618    129 0.000824      14
# 3721       Kenya 0.000558      8 0.011007      41
# 3722    Kenyatta 0.000905     11 0.000815       8
# 3730       Kerry 0.025052     67 0.026162      55
# 3738       Kevin 0.573209     87 0.000895      12
# 3763       Kiley 0.000087      2 0.006757      30
# 3765         Kim 0.017030     49 0.092133      48
# 3773    Kimberly 0.001550     27 0.444646      63
# 3785       Kirby 0.009262    110 0.000542       4
# 3821        Kris 0.006231     42 0.006354      29
# 3827     Kristen 0.000086      2 0.116768      63
# 3829    Kristian 0.007354     42 0.001966      14
# 3831     Kristin 0.000179      4 0.098070      69
# 3855        Kyle 0.228806    111 0.002808      27
# 3869        Lacy 0.007789     84 0.009089      47
# 3907      Lannie 0.000255      5 0.000290       6
# 3918       Larry 0.482597    129 0.000829      16
# 3923     Lashawn 0.000483      9 0.002958      17
# 3945       Laura 0.000611     10 0.656010     129
# 3948      Laurel 0.000659     13 0.023539     103
# 3949      Lauren 0.002893     56 0.226904      64
# 3955      Laurie 0.000233      4 0.087402      73
# 3963      Lavern 0.007846     63 0.004036      49
# 3965     Laverne 0.012317     71 0.034391      83
# 3968       Lavon 0.000489     11 0.003859      46
# 4002         Lee 0.253229    129 0.049190     111
# 4008       Leigh 0.002288     47 0.020949      52
# 4028        Lena 0.000233      4 0.234391     129
# 4031      Lennie 0.001244     26 0.007033      54
# 4039         Leo 0.222190    129 0.001533      27
# 4043       Leona 0.000123      2 0.142728     102
# 4066      Lesley 0.002227     48 0.017639      67
# 4068      Leslie 0.121929    118 0.142529     129
# 4071      Lessie 0.000229      4 0.021648      76
# 4073      Lester 0.163574    119 0.000148       3
# 4123     Lillian 0.002286     30 0.539659     129
# 4126      Lillie 0.001125     17 0.270916     106
# 4135       Linda 0.001710     27 0.837364     129
# 4139     Lindsay 0.003353     59 0.066467      40
# 4140     Lindsey 0.007034    102 0.078530      35
# 4141       Lindy 0.000533      5 0.002083      24
# 4147      Linnie 0.000165      3 0.015751      66
# 4154        Lisa 0.001001     16 0.525698      72
# 4184       Logan 0.101786    107 0.008420      21
# 4185        Lois 0.002752     41 0.298366     104
# 4186        Lola 0.000122      2 0.100458     106
# 4193      London 0.001144      9 0.003307      11
# 4199       Lonie 0.001767     24 0.002922      32
# 4201      Lonnie 0.086462    123 0.006004      77
# 4204        Lora 0.000198      3 0.047557     113
# 4213       Loren 0.037636    119 0.004152      30
# 4217     Lorenza 0.001493     34 0.000197       4
# 4241         Lou 0.002908     40 0.040166      92
# 4246       Louie 0.029363    113 0.003824      38
# 4247       Louis 0.492879    129 0.001364      25
# 4249      Louise 0.002583     38 0.447190     110
# 4254        Love 0.000729     11 0.000304       6
# 4283     Lucille 0.000202      3 0.245179     102
# 4292        Lucy 0.000295      5 0.235303     129
# 4296         Lue 0.000245      4 0.008999      68
# 4306        Lula 0.000254      4 0.187054      86
# 4314        Lupe 0.003596     52 0.013070      73
# 4333         Lyn 0.000123      4 0.003118      31
# 4340        Lynn 0.041629    107 0.099731      92
# 4345       Lyric 0.000192      2 0.002815      14
# 4346       Mabel 0.001195     17 0.327492      85
# 4360   Mackenzie 0.002942     17 0.045843      33
# 4378     Madison 0.006808     73 0.137202      24
# 4384         Mae 0.000432      7 0.193849      90
# 4395      Maggie 0.000279      4 0.171415     129
# 4437       Mamie 0.000171      3 0.166745      87
# 4451      Mannie 0.000788     12 0.000411       7
# 4484    Margaret 0.005515     62 1.360965     129
# 4509       Maria 0.000733     16 0.334567     129
# 4512      Marian 0.000237      4 0.131144     114
# 4522       Marie 0.002013     25 0.655181     129
# 4535      Marion 0.094090    115 0.222235     108
# 4546        Mark 0.711467    129 0.000910      13
# 4562       Marlo 0.000190      4 0.002213      11
# 4564      Marlyn 0.001054     16 0.002366      24
# 4585      Martha 0.001221     20 0.617683     129
# 4591       Marty 0.015632     60 0.001016      18
# 4595        Mary 0.022255     93 4.511860     129
# 4626     Matthew 0.797008    129 0.001848      15
# 4628      Mattie 0.001191     17 0.248461     111
# 4630        Maud 0.000099      2 0.054636      53
# 4631       Maude 0.000747     11 0.170933      71
# 4635     Maurice 0.119992    129 0.000664      13
# 4643       Maxie 0.004003     62 0.004174      57
# 4651         May 0.000732     11 0.113139      84
# 4666    Mckinley 0.011808     76 0.000281       2
# 4689     Melissa 0.000924     18 0.419549     119
# 4713    Meredith 0.003428     55 0.038581      97
# 4716       Merle 0.033522     98 0.018048      77
# 4744       Micah 0.028159     50 0.004201      29
# 4746     Michael 2.366102    129 0.010835      57
# 4753     Michele 0.000229      6 0.122328      64
# 4756    Michelle 0.000997     16 0.439688      71
# 4758      Mickey 0.014701     84 0.003130      40
# 4782     Mildred 0.001890     25 0.549653     104
# 4805      Minnie 0.002169     24 0.411292      92
# 4849     Montana 0.000593      7 0.002533      14
# 4853      Montie 0.000157      3 0.000387       7
# 4860      Morgan 0.027189    129 0.093010      33
# 4891        Myrl 0.000163      3 0.002005      32
# 4899      Myrtle 0.000949     13 0.293053      85
# 4905       Nakia 0.000759      3 0.003476      16
# 4914       Nancy 0.000903     18 0.704694     129
# 4961      Nellie 0.001178     16 0.315955      99
# 4988    Nicholas 0.456540    129 0.000254       3
# 4999      Nicole 0.000324      7 0.308664      63
# 5027        Noel 0.027976    127 0.005108      52
# 5041        Nora 0.000740     12 0.168684     129
# 5072        Ocie 0.002750     40 0.006540      54
# 5079         Oda 0.000165      3 0.002484      31
# 5084       Odell 0.013768     84 0.003943      37
# 5087        Odie 0.003835     45 0.002441      34
# 5096         Ola 0.000652     10 0.051119      78
# 5109        Olie 0.000390      7 0.000182       3
# 5114       Olive 0.000108      2 0.096495      73
# 5118       Ollie 0.030710     92 0.078573      81
# 5134        Opal 0.000500      8 0.083219      81
# 5137         Ora 0.014886     64 0.071301      83
# 5139        Oral 0.003650     44 0.000097       2
# 5162       Orrie 0.000405      6 0.000110       2
# 5177        Osie 0.000326      5 0.001763      27
# 5178       Ossie 0.000987     15 0.003351      47
# 5189       Ottie 0.000172      3 0.002356      33
# 5202        Ozie 0.000255      4 0.000119       2
# 5216      Pamela 0.000064      2 0.318522      84
# 5223       Paris 0.004411     63 0.008053      24
# 5225      Parker 0.029679    108 0.001878      10
# 5232         Pat 0.024116     94 0.029063      56
# 5238    Patricia 0.002490     41 0.999798     123
# 5240       Patsy 0.008071     51 0.088214      96
# 5244        Paul 1.073593    129 0.001739      28
# 5249     Pauline 0.000181      3 0.259994     118
# 5253      Payton 0.008178     22 0.013386      17
# 5254       Pearl 0.013243     59 0.315576     106
# 5259     Pearlie 0.000356      6 0.023057      81
# 5282      Peyton 0.013884     26 0.014670      17
# 5293     Phoenix 0.002282     13 0.000952       6
# 5325     Presley 0.000199      3 0.002819      11
# 5346       Quinn 0.010411     50 0.002584      15
# 5353      Rachel 0.000095      2 0.344009     129
# 5372       Ralph 0.469357    129 0.000099       2
# 5387       Randy 0.162957     74 0.001645      19
# 5401       Raven 0.000492      6 0.016895      32
# 5402         Ray 0.221010    129 0.006726      57
# 5408     Raymond 0.710208    129 0.000545       9
# 5414      Reagan 0.001363     13 0.010955      20
# 5427       Reese 0.007333     74 0.005638       9
# 5429       Regan 0.000355      9 0.005692      26
# 5438      Reilly 0.001067     12 0.001288       8
# 5451        Rene 0.027981    120 0.010041      46
# 5488     Richard 1.829625    129 0.004861      57
# 5494       Ricki 0.000515     10 0.000376       5
# 5502       Riley 0.045098    129 0.024857      19
# 5514      Robbie 0.010092     64 0.017217      91
# 5515      Robbin 0.000386     11 0.003590      21
# 5517      Robert 3.821662    129 0.015059     106
# 5520       Robin 0.022073     77 0.152306      73
# 5556        Roma 0.000117      2 0.006168      63
# 5567      Ronald 0.663841    125 0.000563      11
# 5575      Ronnie 0.099840     81 0.002217      23
# 5578        Rory 0.010253     62 0.000247       2
# 5593     Rosario 0.003053     35 0.002488      36
# 5596        Rose 0.002512     31 0.575952     129
# 5615      Rossie 0.000119      2 0.001955      27
# 5618       Rowan 0.002173     10 0.001360       6
# 5628         Roy 0.490522    129 0.000518      10
# 5638        Ruby 0.004210     51 0.348119     129
# 5657        Ruth 0.003870     48 0.942272     129
# 5664        Ryan 0.427666     64 0.009201      35
# 5670       Rylee 0.000870      8 0.011013      15
# 5684        Sage 0.002719     18 0.004454      16
# 5704      Sammie 0.017161     97 0.005397      63
# 5715      Sandra 0.000718     17 0.512602      95
# 5716       Sandy 0.010075     98 0.036368      71
# 5729      Santos 0.009448    107 0.000815      15
# 5731       Sarah 0.001227     20 0.817214     129
# 5755       Scott 0.413280    129 0.000144       2
# 5800       Shane 0.091574     56 0.000368       3
# 5816     Shannon 0.027716     68 0.164113      72
# 5817      Shanon 0.000464      9 0.001733      15
# 5839      Sharon 0.000750     17 0.419042      84
# 5846       Shaun 0.034709     57 0.000331       5
# 5852       Shawn 0.155895     62 0.017382      40
# 5858        Shay 0.000794     15 0.000240       3
# 5863        Shea 0.002921     35 0.003979      31
# 5871      Shelby 0.012950    120 0.071356      74
# 5874     Shelley 0.000374      6 0.038806      54
# 5876     Shellie 0.000230      4 0.004335      31
# 5877      Shelly 0.000645     11 0.045334      52
# 5889    Sheridan 0.000360      6 0.000619       5
# 5899    Sherrill 0.000654     14 0.003590      31
# 5916     Shirley 0.011590     76 0.516269     127
# 5933      Sidney 0.100683    129 0.011627      80
# 5965      Skylar 0.006258     28 0.014589      19
# 5966      Skyler 0.013751     28 0.007466      19
# 5995      Stacey 0.006732     43 0.082326      57
# 5999       Stacy 0.011785     69 0.090874      59
# 6019   Stephanie 0.000479      9 0.398594     112
# 6028      Steven 0.660196    129 0.000338       5
# 6029      Stevie 0.005351     45 0.002418      16
# 6048       Susan 0.000900     25 0.669830     129
# 6068      Sydney 0.008906     80 0.069485      64
# 6118       Tammy 0.000273      7 0.181217      52
# 6165      Tayler 0.000461      6 0.004637      18
# 6166      Taylor 0.058054    129 0.140101      30
# 6169      Teagan 0.000626      5 0.002673      10
# 6200       Terry 0.230122    127 0.051595      69
# 6217      Thelma 0.000574      8 0.248642      99
# 6218        Theo 0.005976     62 0.004285      50
# 6232      Thomas 1.901267    129 0.004881      73
# 6267     Timothy 0.560668    129 0.000359       5
# 6283        Toby 0.015893     76 0.002126      24
# 6297      Tommie 0.033306    112 0.015670      88
# 6315        Tory 0.002629     28 0.000201       2
# 6324      Tracey 0.003617     24 0.047287      47
# 6327       Tracy 0.034754    116 0.139902      69
# 6356    Trinidad 0.001636     30 0.001445      17
# 6357     Trinity 0.000410      7 0.023456      22
# 6362     Tristan 0.034071     38 0.001202      10
# 6363     Tristen 0.006175     14 0.000500       4
# 6385       Tyler 0.254245     68 0.006904      24
# 6411     Unknown 0.005041     47 0.003426      18
# 6425   Valentine 0.007542     73 0.000116       2
# 6479       Verne 0.008381     76 0.000291       5
# 6480     Vernell 0.000421     13 0.004390      43
# 6486      Vernie 0.003701     46 0.006210      55
# 6488      Vernon 0.137906    124 0.000460       9
# 6528       Viola 0.000144      2 0.209775      93
# 6538      Virgie 0.000139      2 0.035162      77
# 6539      Virgil 0.087506    112 0.000352       7
# 6540    Virginia 0.000753     16 0.573469     129
# 6546      Vivian 0.004022     50 0.155002     129
# 6565      Walter 0.905720    129 0.002561      40
# 6609     Whitney 0.002492     43 0.047696      47
# 6625        Will 0.137696    129 0.000190       3
# 6632     William 4.409453    129 0.015104     108
# 6636      Willie 0.575889    129 0.199790      93
# 6653      Winnie 0.000110      2 0.035808      76
# 6772        Zion 0.005389     11 0.000737       4

# %% [markdown]
# # %%R -h 900 -w 900
#
# times$both <- with(times, boys_n > 10 & girls_n > 10)
#
# # Still a few too many names.  Lets focus on names that have managed a certain
# # level of popularity.
#
# print(qplot(pmin(boys, girls), data = subset(times, both), binwidth = 0.01))
# print(qplot(pmax(boys, girls), data = subset(times, both), binwidth = 0.1))
# print(qplot(boys + girls, data = subset(times, both), binwidth = 0.1))
#
# both_sexes <- subset(times, both & boys + girls > 0.4)
# selected_names <- both_sexes$name
# print(selected_names)

# %% [markdown]
# ## Please fix 'lratio' so this code (for exploring gender differences) works:

# %%
# %%R -w 900 -h 900
#
# # Now that we have figured out which names we should focus on (at least to
# # begin with), we need to calculate yearly summaries for each of those names.
#
# selected <- subset(bnames, name %in% selected_names)
#
# print( nrow(selected) / nrow(bnames) )
#
# # For each name in each year, figure out total boys and total girls
# bysex <- ddply(selected, c("name", "year"), summarize,
#   boys = sum(percent[sex == "boy"]),
#   girls = sum(percent[sex == "girl"]),
#   .progress = "text"
# )
#
# # It's useful to have a symmetric means of comparing the relative abundance
# # of boys and girls - the log ratio is good for this.
#
# bysex$lratio <- log10(bysex$boys / bysex$girls)
# bysex$lratio[!is.finite(bysex$lratio)] <- NA
#
#
# ######  PROBLEM:  lratio wants to be defined differently here ---
# ######  it can have infinite values, and these are set to "null" (NA)
#
# ######  PLEASE define lratio to be some other measure of
# ######   the relative abundance of boys and girls that is always defined.
#
#
# # Explore the distribution of lratio for each name.  This is why a smaller
# # number of names helps - we can more easily see the name associated with the
# # pattern and use our knowledge of names to determine whether or not it's
# # plausible that the name is used for both sexes.
#
# print(qplot(lratio, reorder(name, lratio, na.rm = T), data = bysex))
# print(qplot(abs(lratio), reorder(name, lratio, na.rm = T), data = bysex))
# Out:
# [1] 0.05553101
#   |======================================================================| 100%

# %%
# %%R -w 900 -h 900
#
# print(
#     qplot(abs(lratio), reorder(name, lratio, na.rm = T), data = bysex)
#              # +  geom_point(data = both_sexes, color = "red")
#      )
#
# ##### the "+ geom_point..."  above apparently fails because lratio can have 'NA' values
#
# print(qplot(year, lratio, data = bysex, group = name, geom = "line"))

# %%
# %%R -w 900 -h 900
#
# # Two things seem to be helpful in differentiating true dual-sex names from
# # errors: the average position and the amount of spread.
# #
# # Brainstorm: how could we summarize these things quantitatively?
# # Your turn: Compute the mean and range of lratio for each name
#
# ##### PROBLEM:  lratio is needed for this to work:
#
# rng <- ddply(bysex, "name", summarize,
#   diff = diff(range(lratio, na.rm = T)),
#   mean = mean(lratio, na.rm = T)
# )
#
# print(qplot(diff, abs(mean), data = rng))
# print(qplot(diff, abs(mean), data = rng, color = abs(mean) < 1.75 | diff > 0.9))
#
# shared_names <- subset(rng, abs(mean) < 1.75 | diff > 0.9)$name
#
# print(qplot(abs(lratio), reorder(name, lratio, na.rm=T),
#   data = subset(bysex, name %in% shared_names)))

# %%
# %%R -w 900 -h 900
#
# # Dual-sex names -------------------------------------------------------------
#
# shared <- subset(bysex, name %in% shared_names)
#
# ##### PROBLEM:  lratio is needed for this to work:
#
#
# #####  remember:  print(qplot(...))
#
#
# qplot(year, lratio, data = shared, geom = "line") + facet_wrap(~ name)
#
# # lratio useful because it's symmetric, but probably easier to switch back to
# # something more familiar.
#
# qplot(year, boys / (boys + girls), data = shared, geom = "line") + facet_wrap(~ name)

# %%
# %%R -w 900 -h 900
#
# # What's going on with Carol?  Let's go back to the raw data
#
#
# #####  remember:  print(qplot(...))
#
#
#
# qplot(year, percent, data = subset(bnames, name == "Carol"), color = sex)
#
# # How about Shirley?
#
# qplot(year, percent, data = subset(bnames, name == "Shirley"), color = sex)

# %%
# %%R -w 900 -h 900
#
# # Your turn: what is alike about these patterns?
#
# ###### Answer: Sex encoding errors ? --------------------------------------------------------
#
# errors <- subset(bysex, !(name %in% shared_names))
#
#
# #####  remember:  print(qplot(...))
#
#
# qplot(year, lratio, data = errors, group = name, geom = "line")
#
# qplot(year, abs(lratio), data = errors, group = name, geom = "line",
#   color = lratio > 0)
#
# # Your turn: What do you see in this plot?   Do you think we can use this data
# # to estimate sex-encoding errors?  Why/Why not?

# %% [markdown]
# ## Find the top 5 names for each year, and plot their history

# %%
# %%R -w 600 -h 400
#
# ranked <- ddply(bnames, .(sex, year), transform, rank = rank(-percent))
#
# top5 <- subset(ranked, rank <= 5)
# top5$name <- as.character(top5$name)
#
#
# #####  remember:  print(qplot(...))
#
#
#
# qplot(year, reorder(name, year, min), data = top5, group = name, geom = "text", label = rank) + facet_wrap(~ sex, scales = "free_y")
#
# qplot(year, reorder(name, year, min), data = top5, group = name, color = rank) + facet_wrap(~ sex, scales = "free_y")
#
# qplot(year, percent, data = top5, group = name, color = rank) +
#   facet_wrap(~ name) +
#   scale_x_continuous(breaks = c(1880, 1920, 1960, 2000))

# %% [markdown]
# # Problem 3.  Plot the boy vs. girl percentages of "Lesley-like" names over time

# %% [markdown]
# ## As is done in the "Python for Data Analysis" book (p.42) -- but using R instead of Python -- please plot the history of gender differences in names that start with "Lesl"...

# %%
# %%R
#
# Lesley_like_names = c("Leslie", "Lesley", "Leslee", "Lesli", "Lesly")
#
# #  Using R, figure out how to print the history of Lesley-like names over time for each gender.
#
# #  That is, treating all these names as equivalent, plot the boy vs. girl percentages of
# #  these name occurrences over time.
#
# #  Initially the boy percentage is about 90%, but this changes over time.

# %% [markdown]
# # Optional Problem:
#
# Ignoring gender, are there any names whose percentages always trend up,
# and which appear in at least 15 different years?

# %% [markdown]
# ### (In other words, with an "up-trending" name, its percentage values never decrease over time.)

# %%
# %%R
#
# # .....

# %% [markdown]
# # Optional Problem for Wizards:  get Hadley's Analysis for Baby Names by States to work

# %%
# %%R
#
# # library(ggplot2)
# # library(plyr)
#
# # Try and find names that vary a lot between the states.
#
# bnames <- read.csv("baby-names-by-state.csv", stringsAsFactors = F)
# bnames <- subset(bnames, !is.na(number))
# bnames$state <- factor(bnames$state)
#
# # Add number of births and convert to percentage
# births <- read.csv("births.csv")
# bnames <- merge(bnames, births, by = c("state", "year", "sex"))
# bnames$percent <- bnames$number / bnames$births
#
# # Extract only names that have appeared in at least 25% of possible years
# # and states
# bnames$namesex <- paste(bnames$name, bnames$sex, sep = "-")
# counts <- ddply(bnames, c("namesex"), summarize,
#   n = length(namesex),
#   number = sum(number))
# counts <- counts[order(-counts$number), ]
# counts <- subset(counts, n > 1250 * 0.25 & number > 1e5)
#
# top <- subset(bnames, namesex %in% counts$namesex)
# show_name <- function(name) {
#   one <- top[top$namesex == name, ]
#   qplot(year, percent, data = one, geom = "line", group = state)
# }
#
# # Look for names where there is a lot of variation in pattern between states
#
# # Correlation approach
# bystate <- cast(top, namesex + year ~ state, value = "percent")
#
# cors <- dlply(bystate, "namesex", function(df)
#   cor(as.matrix(df[, -(1:2)]), use = "pairwise.complete.obs"))
#
# arrange(ldply(cors, min, na.rm = T), V1)
#
# # Modelling approach - seems to do much better
# patterns <- dlply(top, c("namesex"), function(df) {
#   lm(percent ~ factor(year), data = df, weight = sqrt(births))
# }, .progress = "text")
#
# rsq <- function(mod) {
#   summarize(summary(mod), rsq = r.squared, sigma = sigma)
# }
# qual <- arrange(merge(ldply(patterns, rsq), counts), -rsq)
#
# sub <- c(as.character(qual$namesex[seq(1, nrow(qual), by = 5)]), "Juan-boy")
#
# interesting <- subset(bnames, namesex %in% sub)
#
# print(interesting)
#
# # write.table(interesting, "interesting-names.csv", sep = ",", row = F)
# Out:
# Error in eval(expr, envir, enclos) : could not find function "cast"

# %% [markdown]
# # Optional Problem for Wizards:  get Hadley's Analysis for Biblical Baby Names to work

# %%
# %%R
#
# # Bibical naming trends
#
# oldt <- scan("old-testament.txt", "")
# bnames <- read.csv("baby-names.csv")
#
# oldt_names <- bnames[bnames$name %in% oldt, ]
#
# # library(plyr)
#
# oldt_sum <- ddply(oldt_names, .(year, sex),
#                   function(df) data.frame(percent = sum(df$percent), n = nrow(df)))
#
# # library(ggplot2)
#
# print( qplot(year, percent, data = oldt_sum, color = sex, geom = "line") )
# print( qplot(year, n, data = oldt_sum, color = sex, geom = "line") )
#
# total <- ddply(oldt_names, .(sex, name), colwise(sum, "percent"))
#
# print( total[order(-total$percent)[1:20], ] )
# Out:
# Error in file(file, "r") : cannot open the connection
# In addition: Warning messages:
# 1: Removed 7555 rows containing missing values (geom_point).
# 2: Removed 7555 rows containing missing values (geom_point).
# 3: Removed 7555 rows containing missing values (geom_point).
# 4: Removed 6561 rows containing missing values (geom_path).
# 5: Removed 612 rows containing missing values (geom_point).
# 6: In file(file, "r") :
#   cannot open file 'old-testanent.txt': No such file or directory
# Error in file(file, "r") : cannot open the connection
